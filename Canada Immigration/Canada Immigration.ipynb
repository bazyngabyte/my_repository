# %% [markdown]
# # Immigration to Canada from 1980 to 2013
#
# ### Website Link: [United Nations](https://www.un.org/development/desa/pd/data/international-migration-flows)
# ### Data source: [Download Data - Excel File](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/Canada.xlsx)
# ### Credits to: United Nations - IBM Team

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "https://upload.wikimedia.org/wikipedia/commons/4/4d/Logo_of_the_United_Nations.svg")
# Out:
# <img src="https://upload.wikimedia.org/wikipedia/commons/4/4d/Logo_of_the_United_Nations.svg"/>

# %% [markdown]
# Image Source: https://upload.wikimedia.org/wikipedia/commons/4/4d/Logo_of_the_United_Nations.svg

# %%
# Importing libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from pywaffle import Waffle
import warnings
warnings.simplefilter(action="ignore",category=FutureWarning)
import datetime as dt
pd.options.mode.chained_assignment = None

# %%
# Importing Data

filepath="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/Canada.xlsx"
df=pd.read_excel(filepath,
sheet_name="Canada by Citizenship",
skiprows=range(20),
skipfooter=2)

# %% [markdown]
# ### 1. Exploring Data

# %%
df.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %%
df.shape
f"{df.shape[0]} Rows by {df.shape[1]} Columns"
# Out:
# '195 Rows by 43 Columns'

# %%
df.describe()
# Out:
#              AREA          REG         DEV          1980          1981  \
# count  195.000000   195.000000  195.000000    195.000000    195.000000
# mean   912.764103  1249.015385  901.753846    508.394872    566.989744
# std     13.082835  1185.526885    0.431878   1949.588546   2152.643752
# min    903.000000   905.000000  901.000000      0.000000      0.000000
# 25%    903.000000   914.000000  902.000000      0.000000      0.000000
# 50%    908.000000   922.000000  902.000000     13.000000     10.000000
# 75%    922.000000   925.500000  902.000000    251.500000    295.500000
# max    935.000000  5501.000000  902.000000  22045.000000  24796.000000
#
#                1982          1983          1984         1985         1986  \
# count    195.000000    195.000000    195.000000   195.000000   195.000000
# mean     534.723077    387.435897    376.497436   358.861538   441.271795
# std     1866.997511   1204.333597   1198.246371  1079.309600  1225.576630
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 43 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Type      195 non-null    object
#  1   Coverage  195 non-null    object
#  2   OdName    195 non-null    object
#  3   AREA      195 non-null    int64
#  4   AreaName  195 non-null    object
#  5   REG       195 non-null    int64
#  6   RegName   195 non-null    object
#  7   DEV       195 non-null    int64
#  8   DevName   195 non-null    object
#  9   1980      195 non-null    int64
#  10  1981      195 non-null    int64
#  11  1982      195 non-null    int64
#  12  1983      195 non-null    int64
#  13  1984      195 non-null    int64
#  14  1985      195 non-null    int64
#  15  1986      195 non-null    int64
#  16  1987      195 non-null    int64
#  17  1988      195 non-null    int64
#  18  1989      195 non-null    int64
#  19  1990      195 non-null    int64
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=195, step=1)

# %% [markdown]
# ### 2. Cleaning up the Data!

# %%
df
# Out:
#            Type    Coverage          OdName  AREA AreaName   REG  \
# 0    Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1    Immigrants  Foreigners         Albania   908   Europe   925
# 2    Immigrants  Foreigners         Algeria   903   Africa   912
# 3    Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4    Immigrants  Foreigners         Andorra   908   Europe   925
# ..          ...         ...             ...   ...      ...   ...
# 190  Immigrants  Foreigners        Viet Nam   935     Asia   920
# 191  Immigrants  Foreigners  Western Sahara   903   Africa   912
# 192  Immigrants  Foreigners           Yemen   935     Asia   922
# 193  Immigrants  Foreigners          Zambia   903   Africa   910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa   910
#
#                 RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0         Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# ...

# %%
# Droping useless columns
df.drop(["AREA","REG","DEV","Type","Coverage","DevName"],axis=1,inplace=True)
df
# Out:
#              OdName AreaName             RegName  1980  1981  1982  1983  \
# 0       Afghanistan     Asia       Southern Asia    16    39    39    47
# 1           Albania   Europe     Southern Europe     1     0     0     0
# 2           Algeria   Africa     Northern Africa    80    67    71    69
# 3    American Samoa  Oceania           Polynesia     0     1     0     0
# 4           Andorra   Europe     Southern Europe     0     0     0     0
# ..              ...      ...                 ...   ...   ...   ...   ...
# 190        Viet Nam     Asia  South-Eastern Asia  1191  1829  2162  3404
# 191  Western Sahara   Africa     Northern Africa     0     0     0     0
# 192           Yemen     Asia        Western Asia     1     2     1     6
# 193          Zambia   Africa      Eastern Africa    11    17    11     7
# 194        Zimbabwe   Africa      Eastern Africa    72   114   102    44
#
#      1984  1985  1986  ...  2004  2005  2006  2007  2008  2009  2010  2011  \
# ...

# %%
# Renaiming columns

df.rename(columns=({"OdName":"Country","AreaName":"Continent","RegName":"Region"}),inplace=True)
df
# Out:
#             Country Continent              Region  1980  1981  1982  1983  \
# 0       Afghanistan      Asia       Southern Asia    16    39    39    47
# 1           Albania    Europe     Southern Europe     1     0     0     0
# 2           Algeria    Africa     Northern Africa    80    67    71    69
# 3    American Samoa   Oceania           Polynesia     0     1     0     0
# 4           Andorra    Europe     Southern Europe     0     0     0     0
# ..              ...       ...                 ...   ...   ...   ...   ...
# 190        Viet Nam      Asia  South-Eastern Asia  1191  1829  2162  3404
# 191  Western Sahara    Africa     Northern Africa     0     0     0     0
# 192           Yemen      Asia        Western Asia     1     2     1     6
# 193          Zambia    Africa      Eastern Africa    11    17    11     7
# 194        Zimbabwe    Africa      Eastern Africa    72   114   102    44
#
#      1984  1985  1986  ...  2004  2005  2006  2007  2008  2009  2010  2011  \
# ...

# %%
# Adding a Total sum Column

integercolumns=df.select_dtypes(include=int)
df["Total"]=integercolumns.sum(axis=1)
df
# Out:
#             Country Continent              Region  1980  1981  1982  1983  \
# 0       Afghanistan      Asia       Southern Asia    16    39    39    47
# 1           Albania    Europe     Southern Europe     1     0     0     0
# 2           Algeria    Africa     Northern Africa    80    67    71    69
# 3    American Samoa   Oceania           Polynesia     0     1     0     0
# 4           Andorra    Europe     Southern Europe     0     0     0     0
# ..              ...       ...                 ...   ...   ...   ...   ...
# 190        Viet Nam      Asia  South-Eastern Asia  1191  1829  2162  3404
# 191  Western Sahara    Africa     Northern Africa     0     0     0     0
# 192           Yemen      Asia        Western Asia     1     2     1     6
# 193          Zambia    Africa      Eastern Africa    11    17    11     7
# 194        Zimbabwe    Africa      Eastern Africa    72   114   102    44
#
#      1984  1985  1986  ...  2005  2006  2007  2008  2009  2010  2011  2012  \
# ...

# %%
# Setting Country Column as Index

df.set_index("Country",inplace=True)
df
# Out:
#                Continent              Region  1980  1981  1982  1983  1984  \
# Country
# Afghanistan         Asia       Southern Asia    16    39    39    47    71
# Albania           Europe     Southern Europe     1     0     0     0     0
# Algeria           Africa     Northern Africa    80    67    71    69    63
# American Samoa   Oceania           Polynesia     0     1     0     0     0
# Andorra           Europe     Southern Europe     0     0     0     0     0
# ...                  ...                 ...   ...   ...   ...   ...   ...
# Viet Nam            Asia  South-Eastern Asia  1191  1829  2162  3404  7583
# Western Sahara    Africa     Northern Africa     0     0     0     0     0
# Yemen               Asia        Western Asia     1     2     1     6     0
# Zambia            Africa      Eastern Africa    11    17    11     7    16
# Zimbabwe          Africa      Eastern Africa    72   114   102    44    32
#
# ...

# %%
# Convertin the column names into strings: '1980' to '2013'.

df.columns = list(map(str, df.columns))

# %%
df.index.name = None
df
# Out:
#                Continent              Region  1980  1981  1982  1983  1984  \
# Afghanistan         Asia       Southern Asia    16    39    39    47    71
# Albania           Europe     Southern Europe     1     0     0     0     0
# Algeria           Africa     Northern Africa    80    67    71    69    63
# American Samoa   Oceania           Polynesia     0     1     0     0     0
# Andorra           Europe     Southern Europe     0     0     0     0     0
# ...                  ...                 ...   ...   ...   ...   ...   ...
# Viet Nam            Asia  South-Eastern Asia  1191  1829  2162  3404  7583
# Western Sahara    Africa     Northern Africa     0     0     0     0     0
# Yemen               Asia        Western Asia     1     2     1     6     0
# Zambia            Africa      Eastern Africa    11    17    11     7    16
# Zimbabwe          Africa      Eastern Africa    72   114   102    44    32
#
# ...

# %% [markdown]
# ### 3. Analyse Data

# %%
# Making copy

canada_df=df.copy()

# %% [markdown]
# #### 3.1 Top 5 Immigration Countries to Canada

# %%
canada_df.sort_values(["Total"],ascending=False,inplace=True)
canada_df
# Out:
#                                                    Continent  \
# India                                                   Asia
# China                                                   Asia
# United Kingdom of Great Britain and Northern Ir...    Europe
# Philippines                                             Asia
# Pakistan                                                Asia
# ...                                                      ...
# San Marino                                            Europe
# New Caledonia                                        Oceania
# Marshall Islands                                     Oceania
# Western Sahara                                        Africa
# Palau                                                Oceania
#
#                                                                 Region   1980  \
# India                                                    Southern Asia   8880
# ...

# %%
years=list(map(str,range(1980,2013)))
top5=canada_df[:5]
top5=top5[years].transpose()
top5
# Out:
#       India  China  United Kingdom of Great Britain and Northern Ireland  \
# 1980   8880   5123                                              22045
# 1981   8670   6682                                              24796
# 1982   8147   3308                                              20620
# 1983   7338   1863                                              10015
# 1984   5704   1527                                              10170
# 1985   4211   1816                                               9564
# 1986   7150   1960                                               9470
# 1987  10189   2643                                              21337
# 1988  11522   2758                                              27359
# 1989  10343   4323                                              23795
# 1990  12041   8076                                              31668
# 1991  13734  14255                                              23380
# ...

# %%
top5.plot(kind='area',figsize=(10,6))
plt.title("Immigration trend of top 5 countries")
plt.ylabel("Number of immigrants")
plt.xlabel("Years")
plt.show()

# %% [markdown]
# #### 3.2 Histogram of Immigration from 195 countries in 2013

# %%
canada_df['2013'].plot(kind='hist')
plt.title("Histogram of Immigration from 195 countries in 2013")
plt.ylabel("Number of Countries")
plt.xlabel("Number of Immigrants")
plt.show()

# %%
# Fixing axis

count,bin_edges=np.histogram(canada_df['2013'])
canada_df['2013'].plot(kind='hist',xticks=bin_edges,figsize=(10,6))
plt.title("Histogram of Immigration from 195 countries in 2013")
plt.ylabel("Number of Countries")
plt.xlabel("Number of Immigrants")
plt.show()

# %% [markdown]
# #### 3.3 Bar Chart Immigration for China and India

# %%
china=canada_df.loc["China",years]
china.plot(kind='bar',figsize=(10,6),color='red')
plt.title("Chinese immigrants to Canada from 1980 to 2013")
plt.xlabel("Year")
plt.ylabel("Number of immigrants")
plt.show()

# %%
india=canada_df.loc["India",years]
india.plot(kind='bar',figsize=(10,6),color='darkorange')
plt.title("Indians immigrants to Canada from 1980 to 2013")
plt.xlabel("Year")
plt.ylabel("Number of immigrants")
plt.show()

# %% [markdown]
# #### 3.4 Pie Chart by Continent

# %%
continent=canada_df.groupby(["Continent"],as_index=False)["Total"].sum().set_index("Continent")
continent
# Out:
#                                    Total
# Continent
# Africa                            618948
# Asia                             3317794
# Europe                           1410947
# Latin America and the Caribbean   765148
# Northern America                  241142
# Oceania                            55174

# %%
continent["Total"].plot(kind='pie',autopct='%1.0f%%',figsize=(10,6))
plt.title("Immigration to Canada by Continent 1980-2013")
plt.show()

# %% [markdown]
# #### 3.4 Box plot Immigration from China to Canada

# %%
china=canada_df.loc[["China"],years].transpose()
china
# Out:
#       China
# 1980   5123
# 1981   6682
# 1982   3308
# 1983   1863
# 1984   1527
# 1985   1816
# 1986   1960
# 1987   2643
# 1988   2758
# 1989   4323
# 1990   8076
# 1991  14255
# 1992  10846
# 1993   9817
# 1994  13128
# 1995  14398
# 1996  19415
# 1997  20475
# 1998  21049
# 1999  30069
# 2000  35529
# 2001  36434
# 2002  31961
# 2003  36439
# 2004  36619
# 2005  42584
# 2006  33518
# 2007  27642
# 2008  30037
# 2009  29622
# 2010  30391
# 2011  28502
# 2012  33024

# %%
china.plot(kind='box')
plt.title("Box Plot for Chinese Immigrants from 1980-2013")
plt.ylabel("Number of Immigrants")
plt.show()

# %% [markdown]
# #### 3.5 Waffle Plot

# %%
icu_df=canada_df.loc[["India","China","Philippines"]]
icu_df
# Out:
#             Continent              Region  1980  1981  1982  1983  1984  1985  \
# India            Asia       Southern Asia  8880  8670  8147  7338  5704  4211
# China            Asia        Eastern Asia  5123  6682  3308  1863  1527  1816
# Philippines      Asia  South-Eastern Asia  6051  5921  5249  4562  3801  3150
#
#              1986   1987  ...   2005   2006   2007   2008   2009   2010  \
# India        7150  10189  ...  36210  33848  28742  28261  29456  34235
# China        1960   2643  ...  42584  33518  27642  30037  29622  30391
# Philippines  4166   7360  ...  18139  18400  19837  24887  28573  38617
#
#               2011   2012   2013   Total
# India        27509  30933  33087  691904
# China        28502  33024  34129  659962
# Philippines  36765  34315  29544  511391
#
# [3 rows x 37 columns]

# %%
icu_df
# Out:
#             Continent              Region  1980  1981  1982  1983  1984  1985  \
# India            Asia       Southern Asia  8880  8670  8147  7338  5704  4211
# China            Asia        Eastern Asia  5123  6682  3308  1863  1527  1816
# Philippines      Asia  South-Eastern Asia  6051  5921  5249  4562  3801  3150
#
#              1986   1987  ...   2005   2006   2007   2008   2009   2010  \
# India        7150  10189  ...  36210  33848  28742  28261  29456  34235
# China        1960   2643  ...  42584  33518  27642  30037  29622  30391
# Philippines  4166   7360  ...  18139  18400  19837  24887  28573  38617
#
#               2011   2012   2013   Total
# India        27509  30933  33087  691904
# China        28502  33024  34129  659962
# Philippines  36765  34315  29544  511391
#
# [3 rows x 37 columns]

# %%
#import Waffle from pywaffle
#Set up the Waffle chart figure

fig = plt.figure(FigureClass = Waffle,
                 rows = 20, columns = 30, #pass the number of rows and columns for the waffle 
                 values = icu_df['Total'], #pass the data to be used for display
                 cmap_name = 'tab20', #color scheme
                 legend = {'labels': [f"{k} ({v})" for k, v in zip(icu_df.index.values,icu_df.Total)],
                            'loc': 'lower left', 'bbox_to_anchor':(0,-0.1),'ncol': 3},
                figsize=(8,8)
                            
                 #notice the use of list comprehension for creating labels 
                 #from index and total of the dataset
                )

#Display the waffle chart
plt.show()
# Out:
# <Waffle size 800x800 with 1 Axes>

# %% [markdown]
# #### 3.5 Choropleth Maps for Immigration

# %%
import folium

# %%
df_can = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/Canada.csv')

# %% [markdown]
# In order to create a `Choropleth` map, we need a GeoJSON file that defines the areas/boundaries of the state, county, or country that we are interested in. In our case, since we are endeavoring to create a world map, we want a GeoJSON that defines the boundaries of all world countries. For your convenience, we will be providing you with this file, so let's go ahead and download it. Let's name it **world_countries.json**.

# %%
import requests

url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/world_countries.json"
response = requests.get(url)

with open("world_countries.json", "wb") as f:
    f.write(response.content)

print('GeoJSON file downloaded!')
# Out:
# GeoJSON file downloaded!

# %%
world_geo = r'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/world_countries.json' # geojson file

# create a plain world map
world_map = folium.Map(location=[0, 0], zoom_start=2)

# %%
# generate choropleth map using the total immigration of each country to Canada from 1980 to 2013
world_map.choropleth(
    geo_data=world_geo,
    data=df_can,
    columns=['Country', 'Total'],
    key_on='feature.properties.name',
    fill_color='YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='Immigration to Canada',
    reset=True
)

# display map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS = false; L_NO_TOUCH = false; L_DISABLE_3D = false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# As per our Choropleth map legend, the darker the color of a country and the closer the color to red, the higher the number of immigrants from that country. Accordingly, the highest immigration over the course of 33 years (from 1980 to 2013) was from China, India, and the Philippines, followed by Poland, Pakistan, and interestingly, the US.
