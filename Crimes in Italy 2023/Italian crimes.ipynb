# %% [markdown]
# # Crimes in Italy 2019 - 2023
#
# ### Website: [Istat](http://dati.istat.it/Index.aspx)
# ### Data source: [Link](http://dati.istat.it/Index.aspx?QueryId=25097&lang=en#)
# ### Wikipedia: [Comuni d'Italia per popolazione](https://it.wikipedia.org/wiki/Comuni_d%27Italia_per_popolazione)

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url="https://shorturl.at/HHicV")
# Out:
# <img src="https://shorturl.at/HHicV"/>

# %% [markdown]
# *Photo credits: Thoughtco. https://www.thoughtco.com/types-of-crimes-3026270

# %%
# Importing libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action="ignore",category=FutureWarning)
import datetime as dt
pd.options.mode.chained_assignment = None

# %%
# Importing Data

filepath="DCCV_DELITTIPS_27112024221041352.csv"
df=pd.read_csv(filepath)

# %% [markdown]
# ### 1. Exploring Data

# %%
df.head()
# Out:
#   ITTER107 Territory TIPO_DATO35  \
# 0    ITC16     Cuneo      CRIMET
# 1    ITC16     Cuneo      CRIMET
# 2    ITC16     Cuneo      CRIMET
# 3    ITC16     Cuneo      CRIMET
# 4    ITC16     Cuneo      CRIMET
#
#                                            Data type  REATI_PS  \
# 0  crimes reported by the police forces to the ju...  CULPINJU
# 1  crimes reported by the police forces to the ju...  CULPINJU
# 2  crimes reported by the police forces to the ju...  CULPINJU
# 3  crimes reported by the police forces to the ju...  CULPINJU
# 4  crimes reported by the police forces to the ju...  CULPINJU
#
#        Type of crime RIF_TIME  Reference period of crime  TIME  Select time  \
# 0  culpable injuries    YRDUR  during the reference year  2019         2019
# 1  culpable injuries    YRDUR  during the reference year  2020         2020
# 2  culpable injuries    YRDUR  during the reference year  2021         2021
# 3  culpable injuries    YRDUR  during the reference year  2022         2022
# 4  culpable injuries    YRDUR  during the reference year  2023         2023
#
#    Value  Flag Codes Flags
# 0   82.5         NaN   NaN
# 1   60.4         NaN   NaN
# 2   70.1         NaN   NaN
# 3   75.3         NaN   NaN
# 4   77.9         NaN   NaN

# %%
df.shape
f"{df.shape[0]} Rows by {df.shape[1]} Columns"
# Out:
# '25145 Rows by 13 Columns'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25145 entries, 0 to 25144
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ITTER107                   25145 non-null  object
#  1   Territory                  25145 non-null  object
#  2   TIPO_DATO35                25145 non-null  object
#  3   Data type                  25145 non-null  object
#  4   REATI_PS                   25145 non-null  object
#  5   Type of crime              25145 non-null  object
#  6   RIF_TIME                   25145 non-null  object
#  7   Reference period of crime  25145 non-null  object
#  8   TIME                       25145 non-null  int64
#  9   Select time                25145 non-null  int64
#  10  Value                      25108 non-null  float64
#  11  Flag Codes                 37 non-null     float64
#  12  Flags                      37 non-null     object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 2.5+ MB

# %% [markdown]
# ### 2. Cleaning up the Data!

# %%
df.head(3)
# Out:
#   ITTER107 Territory TIPO_DATO35  \
# 0    ITC16     Cuneo      CRIMET
# 1    ITC16     Cuneo      CRIMET
# 2    ITC16     Cuneo      CRIMET
#
#                                            Data type  REATI_PS  \
# 0  crimes reported by the police forces to the ju...  CULPINJU
# 1  crimes reported by the police forces to the ju...  CULPINJU
# 2  crimes reported by the police forces to the ju...  CULPINJU
#
#        Type of crime RIF_TIME  Reference period of crime  TIME  Select time  \
# 0  culpable injuries    YRDUR  during the reference year  2019         2019
# 1  culpable injuries    YRDUR  during the reference year  2020         2020
# 2  culpable injuries    YRDUR  during the reference year  2021         2021
#
#    Value  Flag Codes Flags
# 0   82.5         NaN   NaN
# 1   60.4         NaN   NaN
# 2   70.1         NaN   NaN

# %%
df.drop(["ITTER107","TIPO_DATO35","TIPO_DATO35","Data type","REATI_PS","RIF_TIME","Reference period of crime","Select time","Flag Codes","Flags"],axis=1,inplace=True)

# %%
df.rename(columns=({"TIME":"Year"}),inplace=True)

# %%
df.head(20)
# Out:
#    Territory                 Type of crime  Year  Value
# 0      Cuneo             culpable injuries  2019   82.5
# 1      Cuneo             culpable injuries  2020   60.4
# 2      Cuneo             culpable injuries  2021   70.1
# 3      Cuneo             culpable injuries  2022   75.3
# 4      Cuneo             culpable injuries  2023   77.9
# 5      Cuneo                   kidnappings  2019    0.2
# 6      Cuneo                   kidnappings  2020    1.7
# 7      Cuneo                   kidnappings  2021    0.2
# 8      Cuneo                   kidnappings  2022    0.2
# 9      Cuneo                   kidnappings  2023    1.0
# 10     Cuneo               sexual violence  2019    4.4
# 11     Cuneo               sexual violence  2020    5.1
# 12     Cuneo               sexual violence  2021    6.4
# 13     Cuneo               sexual violence  2022    6.0
# 14     Cuneo               sexual violence  2023    7.1
# 15     Cuneo  sexual activity with a minor  2019    0.5
# 16     Cuneo  sexual activity with a minor  2020    0.0
# 17     Cuneo  sexual activity with a minor  2021    1.2
# 18     Cuneo  sexual activity with a minor  2022    0.7
# 19     Cuneo  sexual activity with a minor  2023    0.3

# %%
df.rename(columns=({"Value":"Total"}),inplace=True)

# %%
df
# Out:
#       Territory      Type of crime  Year  Total
# 0         Cuneo  culpable injuries  2019   82.5
# 1         Cuneo  culpable injuries  2020   60.4
# 2         Cuneo  culpable injuries  2021   70.1
# 3         Cuneo  culpable injuries  2022   75.3
# 4         Cuneo  culpable injuries  2023   77.9
# ...         ...                ...   ...    ...
# 25140  Oristano           burglary  2019   86.7
# 25141  Oristano           burglary  2020   82.8
# 25142  Oristano           burglary  2021   52.2
# 25143  Oristano           burglary  2022   68.5
# 25144  Oristano           burglary  2023   56.8
#
# [25145 rows x 4 columns]

# %%
df["Territory"].unique()
# Out:
# array(['Cuneo', 'Asti', 'Alessandria', "Valle d'Aosta / Vallée d'Aoste",
#        'Imperia', 'Savona', 'Genova', 'Ragusa', 'Trento', 'Rieti',
#        'Napoli', 'Trieste', 'Lodi', 'Cosenza', 'Fermo', 'Foggia',
#        'Treviso', 'Venezia', 'Catania', 'Matera', 'Perugia', 'Pistoia',
#        'Lucca', 'Forlì-Cesena', "L'Aquila", 'Modena', 'Pavia', 'Cagliari',
#        'Isernia', 'Bologna', 'Firenze', 'Monza e della Brianza',
#        'Crotone', 'Bari', 'Siracusa', 'Frosinone', 'Pescara', 'Roma',
#        'Prato', 'Terni', 'Agrigento', 'Ascoli Piceno', 'Milano',
#        'Macerata', 'Como', 'Ancona', 'Vicenza', 'Caserta', 'Viterbo',
#        'Verbano-Cusio-Ossola', 'Teramo', 'Biella', 'Latina', 'Vercelli',
#        'Padova', 'Gorizia', 'Ferrara', 'Udine', 'Bolzano / Bozen',
#        'Rimini', 'Pisa', 'Catanzaro', 'Enna', 'Siena', 'Nuoro', 'Taranto',
#        'Salerno', 'Vibo Valentia', 'Belluno', "Reggio nell'Emilia",
#        'Brindisi', 'Barletta-Andria-Trani', 'Benevento', 'Piacenza',
#        'Massa-Carrara', 'Brescia', 'Oristano', 'Ravenna', 'Parma',
#        'Livorno', 'Potenza', 'Reggio di Calabria', 'Sassari', 'Trapani',
#        'Rovigo', 'Messina', 'Novara', 'Avellino', 'Sondrio', 'Verona',
#        'La Spezia', 'Lecco', 'Campobasso',
#        'Trentino Alto Adige / Südtirol', 'Lecce', 'Bergamo', 'Pordenone',
#        'Chieti', 'Torino', 'Grosseto', 'Palermo', 'Pesaro e Urbino',
#        'Varese', 'Mantova', 'Caltanissetta', 'Arezzo', 'Cremona'],
#       dtype=object)

# %% [markdown]
# ## Web Scrapping to extract Italian regions and cities

# %%
url="https://it.wikipedia.org/wiki/Comuni_d%27Italia_per_popolazione"

# %%
italian_cities= pd.read_html(url)[0]
italian_cities
# Out:
#       N°            Comune    Regione Provincia / Città metropolitana  \
# 0      1              Roma      Lazio                            Roma
# 1      2            Milano  Lombardia                          Milano
# 2      3            Napoli   Campania                          Napoli
# 3      4            Torino   Piemonte                          Torino
# 4      5           Palermo    Sicilia                         Palermo
# ..   ...               ...        ...                             ...
# 131  132     Civitavecchia      Lazio                            Roma
# 132  133            Teramo    Abruzzo                          Teramo
# 133  134               Rho  Lombardia                          Milano
# 134  135          Acireale    Sicilia                         Catania
# 135  136  Cava de' Tirreni   Campania                         Salerno
#
#       Abitanti
# 0    2 754 719
# 1    1 371 850
# 2      911 697
# 3      846 926
# 4      628 894
# ..         ...
# 131     51 750
# 132     51 526
# 133     50 847
# 134     50 590
# 135     50 191
#
# [136 rows x 5 columns]

# %%
italian_cities.rename(columns=({"Comune":"City","Regione":"Region"}),inplace=True)
italian_cities
# Out:
#       N°              City     Region Provincia / Città metropolitana  \
# 0      1              Roma      Lazio                            Roma
# 1      2            Milano  Lombardia                          Milano
# 2      3            Napoli   Campania                          Napoli
# 3      4            Torino   Piemonte                          Torino
# 4      5           Palermo    Sicilia                         Palermo
# ..   ...               ...        ...                             ...
# 131  132     Civitavecchia      Lazio                            Roma
# 132  133            Teramo    Abruzzo                          Teramo
# 133  134               Rho  Lombardia                          Milano
# 134  135          Acireale    Sicilia                         Catania
# 135  136  Cava de' Tirreni   Campania                         Salerno
#
#       Abitanti
# 0    2 754 719
# 1    1 371 850
# 2      911 697
# 3      846 926
# 4      628 894
# ..         ...
# 131     51 750
# 132     51 526
# 133     50 847
# 134     50 590
# 135     50 191
#
# [136 rows x 5 columns]

# %%
#Merging Tables

merge_df=pd.merge(left=df,right=italian_cities[["Region","City"]],left_on="Territory",right_on="City",how="inner")
merge_df
# Out:
#       Territory      Type of crime  Year  Total     Region     City
# 0         Cuneo  culpable injuries  2019   82.5   Piemonte    Cuneo
# 1         Cuneo  culpable injuries  2020   60.4   Piemonte    Cuneo
# 2         Cuneo  culpable injuries  2021   70.1   Piemonte    Cuneo
# 3         Cuneo  culpable injuries  2022   75.3   Piemonte    Cuneo
# 4         Cuneo  culpable injuries  2023   77.9   Piemonte    Cuneo
# ...         ...                ...   ...    ...        ...      ...
# 17150   Cremona        shoplifting  2019   94.9  Lombardia  Cremona
# 17151   Cremona        shoplifting  2020   66.1  Lombardia  Cremona
# 17152   Cremona        shoplifting  2021   84.1  Lombardia  Cremona
# 17153   Cremona        shoplifting  2022  111.4  Lombardia  Cremona
# 17154   Cremona        shoplifting  2023  101.5  Lombardia  Cremona
#
# [17155 rows x 6 columns]

# %%
merge_df.isna().sum()
# Out:
# Territory         0
# Type of crime     0
# Year              0
# Total            37
# Region            0
# City              0
# dtype: int64

# %%
merge_df[merge_df["Total"].isna()]
# Out:
#       Territory                     Type of crime  Year  Total     Region  \
# 1655     Napoli                      manslaughter  2019    NaN   Campania
# 1687     Napoli    homicides for theft or robbery  2021    NaN   Campania
# 1796     Napoli                       mass murder  2020    NaN   Campania
# 1799     Napoli                       mass murder  2023    NaN   Campania
# 1873     Napoli             corruption of a minor  2022    NaN   Campania
# 6345       Roma                       mass murder  2019    NaN      Lazio
# 6348       Roma                       mass murder  2022    NaN      Lazio
# 6390       Roma                         smuggling  2019    NaN      Lazio
# 6391       Roma                         smuggling  2020    NaN      Lazio
# 6392       Roma                         smuggling  2021    NaN      Lazio
# 6393       Roma                         smuggling  2022    NaN      Lazio
# 6394       Roma                         smuggling  2023    NaN      Lazio
# 6431       Roma                      infanticides  2020    NaN      Lazio
# 6438       Roma               post office robbery  2022    NaN      Lazio
# 6446       Roma                homicides of mafia  2020    NaN      Lazio
# 6447       Roma                homicides of mafia  2021    NaN      Lazio
# 6533       Roma    homicides for theft or robbery  2022    NaN      Lazio
# 6534       Roma    homicides for theft or robbery  2023    NaN      Lazio
# 6554       Roma        mafia criminal association  2023    NaN      Lazio
# 7328     Milano                       mass murder  2022    NaN  Lombardia
# 7337     Milano                homicides of mafia  2021    NaN  Lombardia
# 7346     Milano                      manslaughter  2020    NaN  Lombardia
# 7348     Milano                      manslaughter  2022    NaN  Lombardia
# 7440     Milano                         smuggling  2019    NaN  Lombardia
# 7444     Milano                         smuggling  2023    NaN  Lombardia
# 7450     Milano    homicides for theft or robbery  2019    NaN  Lombardia
# 7451     Milano    homicides for theft or robbery  2020    NaN  Lombardia
# 7452     Milano    homicides for theft or robbery  2021    NaN  Lombardia
# 15554    Torino             corruption of a minor  2023    NaN   Piemonte
# 15558    Torino                         smuggling  2022    NaN   Piemonte
# 15588    Torino                       mass murder  2022    NaN   Piemonte
# 15589    Torino                       mass murder  2023    NaN   Piemonte
# 15591    Torino        mafia criminal association  2020    NaN   Piemonte
# 15677    Torino    homicides for theft or robbery  2021    NaN   Piemonte
# 15701    Torino  intellectual property violations  2020    NaN   Piemonte
# 15704    Torino  intellectual property violations  2023    NaN   Piemonte
# 15714    Torino                      manslaughter  2023    NaN   Piemonte
#
#          City
# 1655   Napoli
# 1687   Napoli
# 1796   Napoli
# 1799   Napoli
# 1873   Napoli
# 6345     Roma
# 6348     Roma
# 6390     Roma
# 6391     Roma
# 6392     Roma
# 6393     Roma
# 6394     Roma
# 6431     Roma
# 6438     Roma
# 6446     Roma
# 6447     Roma
# 6533     Roma
# 6534     Roma
# 6554     Roma
# 7328   Milano
# 7337   Milano
# 7346   Milano
# 7348   Milano
# 7440   Milano
# 7444   Milano
# 7450   Milano
# 7451   Milano
# 7452   Milano
# 15554  Torino
# 15558  Torino
# 15588  Torino
# 15589  Torino
# 15591  Torino
# 15677  Torino
# 15701  Torino
# 15704  Torino
# 15714  Torino

# %%
merge_df["Total"]= merge_df["Total"].fillna(0)

# %%
merge_df
# Out:
#       Territory      Type of crime  Year  Total     Region     City
# 0         Cuneo  culpable injuries  2019   82.5   Piemonte    Cuneo
# 1         Cuneo  culpable injuries  2020   60.4   Piemonte    Cuneo
# 2         Cuneo  culpable injuries  2021   70.1   Piemonte    Cuneo
# 3         Cuneo  culpable injuries  2022   75.3   Piemonte    Cuneo
# 4         Cuneo  culpable injuries  2023   77.9   Piemonte    Cuneo
# ...         ...                ...   ...    ...        ...      ...
# 17150   Cremona        shoplifting  2019   94.9  Lombardia  Cremona
# 17151   Cremona        shoplifting  2020   66.1  Lombardia  Cremona
# 17152   Cremona        shoplifting  2021   84.1  Lombardia  Cremona
# 17153   Cremona        shoplifting  2022  111.4  Lombardia  Cremona
# 17154   Cremona        shoplifting  2023  101.5  Lombardia  Cremona
#
# [17155 rows x 6 columns]

# %%
merge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17155 entries, 0 to 17154
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Territory      17155 non-null  object
#  1   Type of crime  17155 non-null  object
#  2   Year           17155 non-null  int64
#  3   Total          17155 non-null  float64
#  4   Region         17155 non-null  object
#  5   City           17155 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 804.3+ KB

# %%
italian_crimes= merge_df[["Year","Region","City","Type of crime","Total"]]
italian_crimes
# Out:
#        Year     Region     City      Type of crime  Total
# 0      2019   Piemonte    Cuneo  culpable injuries   82.5
# 1      2020   Piemonte    Cuneo  culpable injuries   60.4
# 2      2021   Piemonte    Cuneo  culpable injuries   70.1
# 3      2022   Piemonte    Cuneo  culpable injuries   75.3
# 4      2023   Piemonte    Cuneo  culpable injuries   77.9
# ...     ...        ...      ...                ...    ...
# 17150  2019  Lombardia  Cremona        shoplifting   94.9
# 17151  2020  Lombardia  Cremona        shoplifting   66.1
# 17152  2021  Lombardia  Cremona        shoplifting   84.1
# 17153  2022  Lombardia  Cremona        shoplifting  111.4
# 17154  2023  Lombardia  Cremona        shoplifting  101.5
#
# [17155 rows x 5 columns]

# %%
grouped_data=italian_crimes.groupby(["City"],as_index=False)["Total"].count()
print(grouped_data.to_string())
# Out:
#              City  Total
# 0       Agrigento    235
# 1     Alessandria    235
# 2          Ancona    235
# 3          Arezzo    235
# 4            Asti    235
# 5        Avellino    235
# 6            Bari    235
# 7       Benevento    235
# 8         Bergamo    235
# 9         Brescia    235
# 10       Brindisi    235
# 11       Cagliari    235
# 12  Caltanissetta    235
# 13        Caserta    235
# 14        Catania    235
# 15      Catanzaro    235
# 16           Como    235
# 17        Cosenza    235
# 18        Cremona    235
# 19        Crotone    235
# 20          Cuneo    235
# 21        Ferrara    235
# 22        Firenze    235
# 23         Foggia    235
# 24         Genova    235
# 25       Grosseto    235
# 26       L'Aquila    235
# 27      La Spezia    235
# 28         Latina    235
# 29          Lecce    235
# 30        Livorno    235
# 31          Lucca    235
# 32         Matera    235
# 33        Messina    235
# 34         Milano    235
# 35         Modena    235
# 36         Napoli    235
# 37         Novara    235
# 38         Padova    235
# 39        Palermo    235
# 40          Parma    235
# 41          Pavia    235
# 42        Perugia    235
# 43        Pescara    235
# 44       Piacenza    235
# 45           Pisa    235
# 46        Pistoia    235
# 47      Pordenone    235
# 48        Potenza    235
# 49          Prato    235
# 50         Ragusa    235
# 51        Ravenna    235
# 52         Rimini    235
# 53           Roma    235
# 54        Salerno    235
# 55        Sassari    235
# 56         Savona    235
# 57          Siena    235
# 58       Siracusa    235
# 59        Taranto    235
# 60         Teramo    235
# 61          Terni    235
# 62         Torino    235
# 63        Trapani    235
# 64         Trento    235
# 65        Treviso    235
# 66        Trieste    235
# 67          Udine    235
# 68         Varese    235
# 69        Venezia    235
# 70         Verona    235
# 71        Vicenza    235
# 72        Viterbo    235

# %%
# Check for Duplicates

italian_crimes[italian_crimes.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Year, Region, City, Type of crime, Total]
# Index: []

# %%
# Data looks spark and clean for analysis

# %%
# Exporting Data

italian_crimes.to_csv("Italian Crimes 2023.csv",index=False)
